# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# ## problem 1

# %%
# part a fitness
pso_pop_sizes = [1, 2, 3, 4, 5,10,15,20,25,30,35,40,45,50,75,100,150,200,300,400,500,600,700,800,900,1000]
pso_avg_fitness = [49.96622474528066, 22.20958358171754, 16.508919149344216, 6.5368701794371376, 7.025466283562037, 3.4896973189806983, 2.5714247182057406, 1.471657153477659, 1.0628779041073657, 1.0001211256122844, 0.8285231907886299, 0.8003306526741596, 1.3963290181965462, 0.8500045177469602, 0.3982540246539685, 0.19991889420878978, 1.724792598736258e-05, 8.491648347330739e-06, 1.0518800763748005e-08, 1.9092723846370064e-09, 2.234088469776907e-11, 1.560636064823484e-11, 8.435890208602359e-10, 4.0117242861015256e-11, 2.0205575879117533e-09, 1.3820056210533949e-11]

plt.figure(figsize=(10,6))
G = sns.lineplot(x=pso_pop_sizes, y=list(map(lambda x: math.log(1+x), pso_avg_fitness)))
#G = sns.lineplot(x=pso_pop_sizes, y=pso_avg_fitness)
G.set_title("Effect of population size on best fitness after 500 generations for PSO on 5D Rastrigin")
G.set_xlabel("Population Size")
G.set_ylabel("log(1 + best fitness)")
G.set_xticks(range(0, 1001, 50))
# Out:
# [<matplotlib.axis.XTick at 0x18fe5bf59a0>,
#  <matplotlib.axis.XTick at 0x18fe5bf5970>,
#  <matplotlib.axis.XTick at 0x18fe5bee520>,
#  <matplotlib.axis.XTick at 0x18fe5c236d0>,
#  <matplotlib.axis.XTick at 0x18fe5c23e20>,
#  <matplotlib.axis.XTick at 0x18fe5c2cc70>,
#  <matplotlib.axis.XTick at 0x18fe5c2c520>,
#  <matplotlib.axis.XTick at 0x18fe5c329a0>,
#  <matplotlib.axis.XTick at 0x18fe5bf5580>,
#  <matplotlib.axis.XTick at 0x18fe5c17670>,
#  <matplotlib.axis.XTick at 0x18fe5c58af0>,
#  <matplotlib.axis.XTick at 0x18fe5c5e5e0>,
#  <matplotlib.axis.XTick at 0x18fe5bfa8e0>,
#  <matplotlib.axis.XTick at 0x18fe5c5ed30>,
#  <matplotlib.axis.XTick at 0x18fe5c63820>,
#  <matplotlib.axis.XTick at 0x18fe5c6a310>,
#  <matplotlib.axis.XTick at 0x18fe5c6adc0>,
#  <matplotlib.axis.XTick at 0x18fe5c630a0>,
#  <matplotlib.axis.XTick at 0x18fe5c6f700>,
#  <matplotlib.axis.XTick at 0x18fe5c771f0>,
#  <matplotlib.axis.XTick at 0x18fe5c77ca0>]

# %%
pso_pop_sizes = [1, 2, 3, 4, 5,10,15,20,25,30,35,40,45,50,75,100,150,200,300,400,500,600,700,800,900,1000]
pso_avg_fitness = [49.96622474528066, 22.20958358171754, 16.508919149344216, 6.5368701794371376, 7.025466283562037, 3.4896973189806983, 2.5714247182057406, 1.471657153477659, 1.0628779041073657, 1.0001211256122844, 0.8285231907886299, 0.8003306526741596, 1.3963290181965462, 0.8500045177469602, 0.3982540246539685, 0.19991889420878978, 1.724792598736258e-05, 8.491648347330739e-06, 1.0518800763748005e-08, 1.9092723846370064e-09, 2.234088469776907e-11, 1.560636064823484e-11, 8.435890208602359e-10, 4.0117242861015256e-11, 2.0205575879117533e-09, 1.3820056210533949e-11]

plt.figure(figsize=(10,6))
G = sns.lineplot(x=pso_pop_sizes[9:], y=list(map(lambda x: math.log(1+x), pso_avg_fitness))[9:])
#G = sns.lineplot(x=pso_pop_sizes, y=pso_avg_fitness)
G.set_title("Effect of population size on best fitness after 500 generations for PSO on 5D Rastrigin")
G.set_xlabel("Population Size")
G.set_ylabel("log(1 + best fitness)")
G.set_xticks(range(30, 1001, 50))
# Out:
# [<matplotlib.axis.XTick at 0x18fea76ba30>,
#  <matplotlib.axis.XTick at 0x18fea76ba00>,
#  <matplotlib.axis.XTick at 0x18fea75e160>,
#  <matplotlib.axis.XTick at 0x18fea79ed00>,
#  <matplotlib.axis.XTick at 0x18fea7ab6a0>,
#  <matplotlib.axis.XTick at 0x18fea7abe80>,
#  <matplotlib.axis.XTick at 0x18fea7b26a0>,
#  <matplotlib.axis.XTick at 0x18fea7ab940>,
#  <matplotlib.axis.XTick at 0x18fea76b610>,
#  <matplotlib.axis.XTick at 0x18fea796b20>,
#  <matplotlib.axis.XTick at 0x18fea7c8550>,
#  <matplotlib.axis.XTick at 0x18fea7c8d30>,
#  <matplotlib.axis.XTick at 0x18fea7d2550>,
#  <matplotlib.axis.XTick at 0x18fea7d2d30>,
#  <matplotlib.axis.XTick at 0x18fea7c8700>,
#  <matplotlib.axis.XTick at 0x18fea7d27c0>,
#  <matplotlib.axis.XTick at 0x18fea7dd430>,
#  <matplotlib.axis.XTick at 0x18fea7ddc10>,
#  <matplotlib.axis.XTick at 0x18fea7e5430>,
#  <matplotlib.axis.XTick at 0x18fea7dd6a0>]

# %%
pso_pop_sizes = [1, 2, 3, 4, 5,10,15,20,25,30,35,40,45,50,75,100,150,200,300,400,500,600,700,800,900,1000]
pso_avg_fitness = [49.96622474528066, 22.20958358171754, 16.508919149344216, 6.5368701794371376, 7.025466283562037, 3.4896973189806983, 2.5714247182057406, 1.471657153477659, 1.0628779041073657, 1.0001211256122844, 0.8285231907886299, 0.8003306526741596, 1.3963290181965462, 0.8500045177469602, 0.3982540246539685, 0.19991889420878978, 1.724792598736258e-05, 8.491648347330739e-06, 1.0518800763748005e-08, 1.9092723846370064e-09, 2.234088469776907e-11, 1.560636064823484e-11, 8.435890208602359e-10, 4.0117242861015256e-11, 2.0205575879117533e-09, 1.3820056210533949e-11]

plt.figure(figsize=(10,6))
G = sns.lineplot(x=pso_pop_sizes, y=pso_avg_fitness)
G.set_title("Effect of population size on best fitness after 500 generations for PSO on 5D Rastrigin")
G.set_xlabel("Population Size")
G.set_ylabel("Best Fitness")
G.set_xticks(range(0, 1001, 50))
# Out:
# [<matplotlib.axis.XTick at 0x18fe5f23c40>,
#  <matplotlib.axis.XTick at 0x18fe5f23c10>,
#  <matplotlib.axis.XTick at 0x18fe5f0f040>,
#  <matplotlib.axis.XTick at 0x18fe5f57fa0>,
#  <matplotlib.axis.XTick at 0x18fe5f61910>,
#  <matplotlib.axis.XTick at 0x18fe5f615b0>,
#  <matplotlib.axis.XTick at 0x18fe5f67910>,
#  <matplotlib.axis.XTick at 0x18fe5f67070>,
#  <matplotlib.axis.XTick at 0x18fe5f23820>,
#  <matplotlib.axis.XTick at 0x18fe5f61a90>,
#  <matplotlib.axis.XTick at 0x18fe5f67e50>,
#  <matplotlib.axis.XTick at 0x18fe5f82790>,
#  <matplotlib.axis.XTick at 0x18fe5f8a8b0>,
#  <matplotlib.axis.XTick at 0x18fe5f82a00>,
#  <matplotlib.axis.XTick at 0x18fe5f57340>,
#  <matplotlib.axis.XTick at 0x18fe5f82ee0>,
#  <matplotlib.axis.XTick at 0x18fe5f95940>,
#  <matplotlib.axis.XTick at 0x18fe5f950a0>,
#  <matplotlib.axis.XTick at 0x18fe5f9d940>,
#  <matplotlib.axis.XTick at 0x18fe5f95730>,
#  <matplotlib.axis.XTick at 0x18fe5f9daf0>]

# %%
pso_pop_sizes = [1, 2, 3, 4, 5,10,15,20,25,30,35,40,45,50,75,100,150,200,300,400,500,600,700,800,900,1000]
pso_avg_fitness = [49.96622474528066, 22.20958358171754, 16.508919149344216, 6.5368701794371376, 7.025466283562037, 3.4896973189806983, 2.5714247182057406, 1.471657153477659, 1.0628779041073657, 1.0001211256122844, 0.8285231907886299, 0.8003306526741596, 1.3963290181965462, 0.8500045177469602, 0.3982540246539685, 0.19991889420878978, 1.724792598736258e-05, 8.491648347330739e-06, 1.0518800763748005e-08, 1.9092723846370064e-09, 2.234088469776907e-11, 1.560636064823484e-11, 8.435890208602359e-10, 4.0117242861015256e-11, 2.0205575879117533e-09, 1.3820056210533949e-11]

plt.figure(figsize=(10,6))
G = sns.lineplot(x=pso_pop_sizes[:14], y=pso_avg_fitness[:14])
G.set_title("Effect of population size on best fitness after 500 generations for PSO on 5D Rastrigin")
G.set_xlabel("Population Size")
G.set_ylabel("Best Fitness")
G.set_xticks([1, 2, 3, 4, 5,10,15,20,25,30,35,40,45,50])
# Out:
# [<matplotlib.axis.XTick at 0x18fea236880>,
#  <matplotlib.axis.XTick at 0x18fea236850>,
#  <matplotlib.axis.XTick at 0x18fe7e74d00>,
#  <matplotlib.axis.XTick at 0x18fea26da00>,
#  <matplotlib.axis.XTick at 0x18fea272340>,
#  <matplotlib.axis.XTick at 0x18fea272b20>,
#  <matplotlib.axis.XTick at 0x18fea27c340>,
#  <matplotlib.axis.XTick at 0x18fea27cb20>,
#  <matplotlib.axis.XTick at 0x18fea236460>,
#  <matplotlib.axis.XTick at 0x18fea272c70>,
#  <matplotlib.axis.XTick at 0x18fea292280>,
#  <matplotlib.axis.XTick at 0x18fea29c3d0>,
#  <matplotlib.axis.XTick at 0x18fea29cbb0>,
#  <matplotlib.axis.XTick at 0x18fea29c970>]

# %%
# part a convergence
pso_pop_sizes = [1, 2, 3, 4, 5,10,15,20,25,30,35,40,45,50,75,100,150,200,300,400,500,600]
pso_avg_conv = [5000.0, 5000.0, 5000.0, 2643.2, 1784.0, 1678.4, 717.2, 674.2, 631.8, 568.2, 566.8, 503.8, 485.4, 481.0, 409.6, 381.0, 360.6, 347.4, 335.2, 323.2, 286.4, 307.0]

plt.figure(figsize=(10,6))
G = sns.lineplot(x=pso_pop_sizes, y=pso_avg_conv)
G.set_title("Effect of population size on avg generations till solution found for PSO on 5D Rastrigin")
G.set_xlabel("Population Size")
G.set_ylabel("Solution found in generation")
G.set_xticks(range(0, 601, 50))
G.set_yticks(range(0, 5001, 500))
# Out:
# [<matplotlib.axis.YTick at 0x18feaa14a00>,
#  <matplotlib.axis.YTick at 0x18feaa143a0>,
#  <matplotlib.axis.YTick at 0x18feaa4b3d0>,
#  <matplotlib.axis.YTick at 0x18feaa58ee0>,
#  <matplotlib.axis.YTick at 0x18feaa58fd0>,
#  <matplotlib.axis.YTick at 0x18feaa619a0>,
#  <matplotlib.axis.YTick at 0x18feaa61580>,
#  <matplotlib.axis.YTick at 0x18fea7966d0>,
#  <matplotlib.axis.YTick at 0x18feaa73790>,
#  <matplotlib.axis.YTick at 0x18feaa4b7c0>,
#  <matplotlib.axis.YTick at 0x18feaa77a60>]

# %%
# part b convergence
# 2: {1: -1, 2: -1, 3: -1, 4: 602, 5: -1, 10: 395, 15: 349, 20: 279, 25: 328, 30: 388, 35: 332, 40: 299, 45: 255, 50: 307, 75: 240, 100: 219, 150: 199, 200: 212, 300: 203, 400: 144, 500: 204}
# 3: {1: -1, 2: -1, 3: -1, 4: 555, 5: 1441, 10: 743, 15: 630, 20: 771, 25: 559, 30: 552, 35: 566, 40: 570, 45: 458, 50: 461, 75: 396, 100: 401, 150: 402, 200: 393, 300: 379, 400: 330, 500: 304}
# 4: {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: 1539, 15: 810, 20: 1184, 25: 988, 30: 905, 35: 784, 40: 586, 45: 877, 50: 756, 75: 666, 100: 667, 150: 632, 200: 547, 300: 515, 400: 531, 500: 445}
# 5: {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: 2215, 15: 1243, 20: 1558, 25: -1, 30: 1418, 35: 1119, 40: 972, 45: 925, 50: 918, 75: 1320, 100: 781, 150: 720, 200: 794, 300: 628, 400: 784, 500: 616}
# 6: {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: -1, 15: 2034, 20: -1, 25: -1, 30: -1, 35: 1668, 40: -1, 45: 1715, 50: 1570, 75: 1088, 100: 1401, 150: 918, 200: 893, 300: 1200, 400: 873, 500: 764}
# 7: {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: -1, 15: -1, 20: -1, 25: -1, 30: 2490, 35: 2327, 40: 1886, 45: 2250, 50: -1, 75: -1, 100: 2087, 150: 1275, 200: 1570, 300: 1100, 400: 993, 500: 1061}
# 8: {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: -1, 15: -1, 20: -1, 25: -1, 30: -1, 35: -1, 40: -1, 45: -1, 50: -1, 75: 2288, 100: 1580, 150: 2037, 200: 1758, 300: 1436, 400: 1611, 500: 1418}
# 9: {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: -1, 15: -1, 20: -1, 25: -1, 30: -1, 35: -1, 40: -1, 45: -1, 50: -1, 75: -1, 100: -1, 150: -1, 200: 2481, 300: 1757, 400: 1816, 500: 1911}
# 10: {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: -1, 15: -1, 20: -1, 25: -1, 30: -1, 35: -1, 40: -1, 45: -1, 50: -1, 75: -1, 100: -1, 150: -1, 200: -1, 300: -1, 400: -1, 500: 2252}

d2 = {1: -1, 2: -1, 3: -1, 4: 602, 5: -1, 10: 395, 15: 349, 20: 279, 25: 328, 30: 388, 35: 332, 40: 299, 45: 255, 50: 307, 75: 240, 100: 219, 150: 199, 200: 212, 300: 203, 400: 144, 500: 204}
d3 = {1: -1, 2: -1, 3: -1, 4: 555, 5: 1441, 10: 743, 15: 630, 20: 771, 25: 559, 30: 552, 35: 566, 40: 570, 45: 458, 50: 461, 75: 396, 100: 401, 150: 402, 200: 393, 300: 379, 400: 330, 500: 304}
d4 = {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: 1539, 15: 810, 20: 1184, 25: 988, 30: 905, 35: 784, 40: 586, 45: 877, 50: 756, 75: 666, 100: 667, 150: 632, 200: 547, 300: 515, 400: 531, 500: 445}
d5 = {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: 2215, 15: 1243, 20: 1558, 25: -1, 30: 1418, 35: 1119, 40: 972, 45: 925, 50: 918, 75: 1320, 100: 781, 150: 720, 200: 794, 300: 628, 400: 784, 500: 616}
d6 = {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: -1, 15: 2034, 20: -1, 25: -1, 30: -1, 35: 1668, 40: -1, 45: 1715, 50: 1570, 75: 1088, 100: 1401, 150: 918, 200: 893, 300: 1200, 400: 873, 500: 764}
d7 = {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: -1, 15: -1, 20: -1, 25: -1, 30: 2490, 35: 2327, 40: 1886, 45: 2250, 50: -1, 75: -1, 100: 2087, 150: 1275, 200: 1570, 300: 1100, 400: 993, 500: 1061}
d8 = {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: -1, 15: -1, 20: -1, 25: -1, 30: -1, 35: -1, 40: -1, 45: -1, 50: -1, 75: 2288, 100: 1580, 150: 2037, 200: 1758, 300: 1436, 400: 1611, 500: 1418}
d9 = {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: -1, 15: -1, 20: -1, 25: -1, 30: -1, 35: -1, 40: -1, 45: -1, 50: -1, 75: -1, 100: -1, 150: -1, 200: 2481, 300: 1757, 400: 1816, 500: 1911}
d10 = {1: -1, 2: -1, 3: -1, 4: -1, 5: -1, 10: -1, 15: -1, 20: -1, 25: -1, 30: -1, 35: -1, 40: -1, 45: -1, 50: -1, 75: -1, 100: -1, 150: -1, 200: -1, 300: -1, 400: -1, 500: 2252}

d2_v = list(map(lambda x: 2500 if x == -1 else x, d2.values()))
d3_v = list(map(lambda x: 2500 if x == -1 else x, d3.values()))
d4_v = list(map(lambda x: 2500 if x == -1 else x, d4.values()))
d5_v = list(map(lambda x: 2500 if x == -1 else x, d5.values()))
d6_v = list(map(lambda x: 2500 if x == -1 else x, d6.values()))
d7_v = list(map(lambda x: 2500 if x == -1 else x, d7.values()))
d8_v = list(map(lambda x: 2500 if x == -1 else x, d8.values()))
d9_v = list(map(lambda x: 2500 if x == -1 else x, d9.values()))
d10_v = list(map(lambda x: 2500 if x == -1 else x, d10.values()))

xs = [1, 2, 3, 4, 5,10,15,20,25,30,35,40,45,50,75,100,150,200,300,400,500]


plt.figure(figsize=(10,6))
G = sns.lineplot(x=xs, y=d2_v, label="2D")
G = sns.lineplot(x=xs, y=d3_v, label="3D")
G = sns.lineplot(x=xs, y=d4_v, label="4D")
G = sns.lineplot(x=xs, y=d5_v, label="5D")
G = sns.lineplot(x=xs, y=d6_v, label="6D")
G = sns.lineplot(x=xs, y=d7_v, label="7D")
G = sns.lineplot(x=xs, y=d8_v, label="8D")
G = sns.lineplot(x=xs, y=d9_v, label="9D")
G = sns.lineplot(x=xs, y=d10_v, label="10D")

G.set_title("Effect of population size on avg generations till solution found for PSO on different dimensions Rastrigin")
G.set_xlabel("Population Size")
G.set_ylabel("Solution found in generation")
G.set_xticks(range(0, 501, 50))
G.set_yticks(range(0, 2501, 500))
sns.move_legend(G, "lower right")

# %%
# part b fitness
#2 {1: 14.476401605964586, 2: 1.9899183823075859, 3: 0.9949590570935314, 4: 0.24174832811938174, 5: 1.4162973727138706e-07, 10: 5.353939513952355e-12, 15: 0.0, 20: 0.0, 25: 0.0, 30: 0.0, 35: 0.0, 40: 0.0, 45: 0.0, 50: 0.0, 75: 0.0, 100: 0.0, 150: 0.0, 200: 0.0, 300: 0.0, 400: 0.0, 500: 0.0}
v = list(map(lambda x: 2500 if x == -1 else log(1+x), d9.values()))
d10_v = list(map(lambda x: 2500 if x == -1 else log(1+x), d10.values()))

xs = [1, 2, 3, 4, 5,10,15,20,25,30,35,40,45,50,75,100,150,200,300,400,500]


plt.figure(figsize=(10,6))
G = sns.lineplot(x=xs, y=d2_v, label="2D")
G = sns.lineplot(x=xs, y=d3_v, label="3D")
G = sns.lineplot(x=xs, y=d4_v, label="4D")
G = sns.lineplot(x=xs, y=d5_v, label="5D")
G = sns.lineplot(x=xs, y=d6_v, label="6D")
G = sns.lineplot(x=xs, y=d7_v, label="7D")
G = sns.lineplot(x=xs, y=d8_v, label="8D")
G = sns.lineplot(x=xs, y=d9_v, label="9D")
G = sns.lineplot(x=xs, y=d10_v, label="10D")

G.set_title("Effect of population size on avg generations till solution found for PSO on different dimensions Rastrigin")
G.set_xlabel("Population Size")
G.set_ylabel("Best fitness after 500 generations (log)")
G.set_xticks(range(0, 501, 50))
G.set_yticks(range(0, 6))
sns.move_legend(G, "upper right")

# %%
plt.figure(figsize=(10,6))

d2_v = list(map(lambda x: 2500 if x == -1 else x, d2.values()))
d3_v = list(map(lambda x: 2500 if x == -1 else x, d3.values()))
d4_v = list(map(lambda x: 2500 if x == -1 else x, d4.values()))
d5_v = list(map(lambda x: 2500 if x == -1 else x, d5.values()))
d6_v = list(map(lambda x: 2500 if x == -1 else x, d6.values()))
d7_v = list(map(lambda x: 2500 if x == -1 else x, d7.values()))
d8_v = list(map(lambda x: 2500 if x == -1 else x, d8.values()))
d9_v = list(map(lambda x: 2500 if x == -1 else x, d9.values()))
d10_v = list(map(lambda x: 2500 if x == -1 else x, d10.values()))

G = sns.lineplot(x=xs[:14], y=d2_v[:14], label="2D")
G = sns.lineplot(x=xs[:14], y=d3_v[:14], label="3D")
G = sns.lineplot(x=xs[:14], y=d4_v[:14], label="4D")
G = sns.lineplot(x=xs[:14], y=d5_v[:14], label="5D")
G = sns.lineplot(x=xs[:14], y=d6_v[:14], label="6D")
G = sns.lineplot(x=xs[:14], y=d7_v[:14], label="7D")
G = sns.lineplot(x=xs[:14], y=d8_v[:14], label="8D")
G = sns.lineplot(x=xs[:14], y=d9_v[:14], label="9D")
G = sns.lineplot(x=xs[:14], y=d10_v[:14], label="10D")

G.set_title("Effect of population size on avg generations till solution found for PSO on different dimensions Rastrigin")
G.set_xlabel("Population Size")
G.set_ylabel("Best fitness after 500 generations (absolute)")
G.set_xticks(range(0, 51, 5))
sns.move_legend(G, "upper right")

# %% [markdown]
# ## problem 2

# %%
# part a and b
xs=[3,4,5,6]
# fitnesses
ys1=[0.0, 0.9, 1.0, 1.0]
ys2=[0,0.17,0.37,0.90]
chart = sns.lineplot(x=xs,y=ys1, label="binary fitness")
chart = sns.lineplot(x=xs, y=ys2, label="scaling fitness")
chart.set_title("GA using binary fitness function vs scaling fitness function")
chart.set_xlabel("Sumplete problem size K")
chart.set_ylabel("Best fitness achieved after 200 generations")
plt.show()

# %%
# part a & b
xs=[3,4,5,6]
# convergence
ys1=[29.9, 181.5, 200.0, 200.0]
ys2=[2.0, 56.4, 121.0, 200.0]
chart = sns.lineplot(x=xs,y=ys1, label="binary fitness")
chart = sns.lineplot(x=xs, y=ys2, label="scaling fitness")
plt.suptitle("GA using binary fitness function vs scaling fitness function")
plt.title("Note: 200 generations == did not convergence")
chart.set_xlabel("Sumplete problem size K")
chart.set_ylabel("Generations taken to converge")
plt.show()

# %%
m_rs = [i/10 for i in range(11)]
mr_fitnesses = [0.78, 0.36, 0.0, 0.0, 0.0, 0.0, 0.13, 0.76, 0.68, 0.83, 0.94]
mr_convs = [161.2, 84.2, 31.8, 19.8, 64.0, 83.2, 135.8, 200, 170.8, 200, 200]

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(m_rs, mr_fitnesses, label="fitness", color='royalblue')
ax2.plot(m_rs, mr_convs, label="convergence", color="darkorange")

ax1.set_xlabel('Mutation Rate')
ax1.set_ylabel('Best Fitness', color='royalblue')
ax2.set_ylabel('Generations till convergence', color='darkorange')

plt.title("Effect of Mutation Rate on Sumplete GA")

plt.show()

# %%
pzs = [1,5,10,15,20,25,30,35,40,45,50,60,70,80,90,100]
pz_fitnesses = [0.19,0.13,0,0,0.18,0,0.13,0,0,0,0,0,0,0,0.17,0]
pz_convs = [134.6,100.8,69.4,72.4,70.4,39.8,77.6,25.4,58.0,42.2,32.0,34.6,48.8,29.0,51.4,15.6]

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(pzs, pz_fitnesses, label="fitness", color='royalblue')
ax2.plot(pzs, pz_convs, label="convergence", color='darkorange')

ax1.set_xlabel('Population Size')
ax1.set_ylabel('Best Fitness', color='royalblue')
ax2.set_ylabel('Generations till convergence', color='darkorange')

plt.title("Effect of Population Size on Sumplete GA")

plt.show()

# %%
gs = [0,100,200,300,400,500]
g_fitnesses = [0.997,0.177,0.184,0.171,0.0, 0.0]

chart=sns.lineplot(x=gs, y=g_fitnesses)

plt.suptitle("Effect of Number of Generations on Sumplete GA")
chart.set_xlabel("Number of Generations")
chart.set_ylabel("Best Fitness")

plt.show()

# %% [markdown]
# ## problem 3

# %%
gens = [56, 7, 38, 4, 9, 1, 44, 181, 35, 23, 87, 66, 102, 44, 84, 249, 50, 28, 10, 158]
avg_gen = sum(gens) / len(gens)
print(avg_gen)

sns.set(style='darkgrid')
g=sns.boxplot(x=gens)
g.set_title("Distribution of generation where solution was obtained using GP for Cullen numbers")
g.set_xlabel("Generation")
g.set_xticks(range(0,251, 25))
# Out:
# 63.8
# [<matplotlib.axis.XTick at 0x18ff39ccdc0>,
#  <matplotlib.axis.XTick at 0x18ff39ccd90>,
#  <matplotlib.axis.XTick at 0x18ff39831c0>,
#  <matplotlib.axis.XTick at 0x18ff3c041c0>,
#  <matplotlib.axis.XTick at 0x18ff3c0eeb0>,
#  <matplotlib.axis.XTick at 0x18ff3c1b850>,
#  <matplotlib.axis.XTick at 0x18ff3c1b070>,
#  <matplotlib.axis.XTick at 0x18ff3c1b910>,
#  <matplotlib.axis.XTick at 0x18ff39cc9a0>,
#  <matplotlib.axis.XTick at 0x18ff3c21f10>,
#  <matplotlib.axis.XTick at 0x18ff3c280a0>]
